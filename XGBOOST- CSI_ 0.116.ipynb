# %% [markdown]
# # drive 마운트, seed 고정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     281             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     282         )
# --> 283       raise ValueError('mount failed' + extra_reason)
#     284     elif case == 4:
#     285       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
import os
import pandas as pd
import numpy as np
import random

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import xgboost as xgb
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from sklearn.cluster import MiniBatchKMeans

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# # 데이터 로드 및 전처리

# %%
train_data  = pd.read_csv('/content/drive/MyDrive/날씨 콘테스트/fog_train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/날씨 콘테스트/fog_test.csv')

# 열 이름 변경
train_data.columns = train_data.columns.str.replace('fog_train.', '')
test_data.columns = test_data.columns.str.replace('fog_test.', '')

# 'Unnamed: 0' 열 제거
train_data.drop(columns=['Unnamed: 0'], inplace=True)
test_data.drop(columns=['Unnamed: 0'], inplace=True)

# 테스트 데이터에서 class 열 제거, 목표변수가 test데이터 열에 포함되면 안되기 때문
test_data = test_data.drop(columns=['class'], errors='ignore')

# 결측값 처리 (-99, -99.9를 NaN으로 대체)
train_data.replace([-99, -99.9], np.nan, inplace=True)
test_data.replace([-99, -99.9], np.nan, inplace=True)

# %%
# hm 컬럼에서 값이 0인 경우를 1로 대체
train_data['hm'] = train_data['hm'].replace(0, 1)

# %% [markdown]
# # 본문

# %%
# train데이터는 총 3개년의 데이터가 있는데 한 년도에 29일이 포함되어잇다.
# test데이터에는 한 년도의 데이터가 있는데 29일이 포함되어잇지 않다.

# %%
train_data['year'] = train_data['year'].replace({'I': 2020, 'J': 2021, 'K': 2022})
test_data['year'] = test_data['year'].replace({'L': 2024})

# %%
# 'time' 열을 'hour' 열로 변경
train_data.rename(columns={'time': 'hour'}, inplace=True)
test_data.rename(columns={'time': 'hour'}, inplace=True)

# %%
# 'datetime' 열 추가
train_data['datetime'] = pd.to_datetime(train_data[['year', 'month', 'day', 'hour', 'minute']])

# %%
# 'datetime' 열 추가
test_data['datetime'] = pd.to_datetime(test_data[['year', 'month', 'day', 'hour', 'minute']])

# %% [markdown]
# # 삼각

# %%
# 삼각함수를 사용한 시계열 특성 생성 함수
def create_sin_cos_features(df):
    # 시간 단위로 변환
    df['seconds_in_day'] = df['hour'] * 3600 + df['minute'] * 60
    df['seconds_in_year'] = (df['datetime'] - pd.to_datetime(df['datetime'].dt.year.astype(str) + '-01-01')).dt.total_seconds()

    # 하루를 기준으로 시간(hour, minute) 변환
    df['time_sin'] = np.sin(2 * np.pi * df['seconds_in_day'] / 86400)
    df['time_cos'] = np.cos(2 * np.pi * df['seconds_in_day'] / 86400)

    # 1년을 기준으로 시간(year, month, day) 변환
    df['yearly_time_sin'] = np.sin(2 * np.pi * df['seconds_in_year'] / (365 * 86400))
    df['yearly_time_cos'] = np.cos(2 * np.pi * df['seconds_in_year'] / (365 * 86400))

    return df

# %%
# 시계열 특성 생성
interpolated_train_data_t = create_sin_cos_features(interpolated_train_data)

print("\nFinal DataFrame with Sin and Cos Features:")
print(interpolated_train_data_t[['datetime', 'time_sin', 'time_cos', 'yearly_time_sin', 'yearly_time_cos']].head())
# Out:
# Final DataFrame with Sin and Cos Features:
#              datetime  time_sin  time_cos  yearly_time_sin  yearly_time_cos
# 0 2020-01-01 00:10:00  0.043619  0.999048         0.000120              1.0
# 1 2020-01-01 00:20:00  0.087156  0.996195         0.000239              1.0
# 2 2020-01-01 00:30:00  0.130526  0.991445         0.000359              1.0
# 3 2020-01-01 00:40:00  0.173648  0.984808         0.000478              1.0
# 4 2020-01-01 00:50:00  0.216440  0.976296         0.000598              1.0

# %%
# 시계열 특성 생성
interpolated_test_data_t = create_sin_cos_features(interpolated_test_data)

print("\nFinal DataFrame with Sin and Cos Features:")
print(interpolated_test_data_t[['datetime', 'time_sin', 'time_cos', 'yearly_time_sin', 'yearly_time_cos']].head())
# Out:
# Final DataFrame with Sin and Cos Features:
#              datetime  time_sin  time_cos  yearly_time_sin  yearly_time_cos
# 0 2024-01-01 00:00:00  0.000000  1.000000         0.000000              1.0
# 1 2024-01-01 00:10:00  0.043619  0.999048         0.000120              1.0
# 2 2024-01-01 00:20:00  0.087156  0.996195         0.000239              1.0
# 3 2024-01-01 00:30:00  0.130526  0.991445         0.000359              1.0
# 4 2024-01-01 00:40:00  0.173648  0.984808         0.000478              1.0

# %%
interpolated_train_data_t.isnull().sum()
# Out:
# datetime                0
# year                    0
# month                   0
# day                     0
# hour                    0
# minute                  0
# stn_id                  0
# ws10_deg                0
# ws10_ms                 0
# ta                      0
# re                      0
# hm                      0
# sun10                   0
# ts                      0
# vis1                    0
# class                   0
# seconds_in_day          0
# seconds_in_year         0
# time_sin                0
# time_cos                0
# yearly_time_sin         0
# yearly_time_cos         0
# Temp_Diff               0
# dew_point               0
# dew_point_minus_ta      0
# sqrt_rounded_diff       0
# Fog_Likelihood_Index    0
# ws10_deg_sin            0
# ws10_deg_cos            0
# dtype: int64

# %%
interpolated_test_data_t.isnull().sum()
# Out:
# datetime                 0
# year                     0
# month                    0
# day                      0
# hour                     0
# minute                   0
# stn_id                   0
# ws10_deg                 0
# ws10_ms                  0
# ta                       0
# re                       0
# hm                       0
# sun10                    0
# ts                      54
# seconds_in_day           0
# seconds_in_year          0
# time_sin                 0
# time_cos                 0
# yearly_time_sin          0
# yearly_time_cos          0
# Temp_Diff               54
# dew_point                0
# dew_point_minus_ta       0
# sqrt_rounded_diff        0
# Fog_Likelihood_Index    54
# ws10_deg_sin             0
# ws10_deg_cos             0
# dtype: int64

# %% [markdown]
# # 파생변수

# %%
interpolated_train_data_t['Temp_Diff'] = interpolated_train_data_t['ta'] - interpolated_train_data_t['ts']
interpolated_test_data_t['Temp_Diff'] = interpolated_test_data_t['ta'] - interpolated_test_data_t['ts']

# %%
#interpolated_train_data_t['Fog_Likelihood_Index'] = (interpolated_train_data_t['Temp_Diff'] * interpolated_train_data_t['hm']) / (interpolated_train_data_t['ws10_ms'] + 1)
#interpolated_test_data_t['Fog_Likelihood_Index'] = (interpolated_test_data_t['Temp_Diff'] * interpolated_test_data_t['hm']) / (interpolated_test_data_t['ws10_ms'] + 1)

# %%
import pandas as pd
import numpy as np

# 매그너스 공식의 상수
a = 17.62
b = 243.12

# 이슬점 계산 함수
def calculate_dew_point(temperature, humidity):
    gamma = (a * temperature) / (b + temperature) + np.log(humidity / 100.0)
    dew_point = (b * gamma) / (a - gamma)
    return dew_point

# %%
# 이슬점 온도 계산 및 컬럼 추가
interpolated_train_data_t['dew_point'] = interpolated_train_data_t.apply(lambda row: calculate_dew_point(row['ta'], row['hm']), axis=1)

# %%
interpolated_test_data_t['dew_point'] = interpolated_test_data_t.apply(lambda row: calculate_dew_point(row['ta'], row['hm']), axis=1)

# %%
interpolated_train_data_t['dew_point_minus_ta'] = -(interpolated_train_data_t['dew_point'] - interpolated_train_data_t['ta']).round(1)

# %%
interpolated_test_data_t['dew_point_minus_ta'] = -(interpolated_test_data_t['dew_point'] - interpolated_test_data_t['ta']).round(1)

# %%
interpolated_train_data_t['sqrt_rounded_diff'] = np.sqrt(interpolated_train_data_t['dew_point_minus_ta'])

# %%
interpolated_test_data_t['sqrt_rounded_diff'] = np.sqrt(interpolated_test_data_t['dew_point_minus_ta'])

# %%
interpolated_train_data_t['Fog_Likelihood_Index'] = (interpolated_train_data_t['Temp_Diff'] * interpolated_train_data_t['hm']) / (interpolated_train_data_t['ws10_ms'] + 1)
interpolated_test_data_t['Fog_Likelihood_Index'] = (interpolated_test_data_t['Temp_Diff'] * interpolated_test_data_t['hm']) / (interpolated_test_data_t['ws10_ms'] + 1)

# %%
# 풍향을 주기적인 특성으로 변환하는 함수
def transform_wind_direction(df):
    df['ws10_deg_sin'] = np.sin(np.deg2rad(df['ws10_deg']))
    df['ws10_deg_cos'] = np.cos(np.deg2rad(df['ws10_deg']))
    return df

# 데이터프레임에 변환 적용
interpolated_train_data_t = transform_wind_direction(interpolated_train_data_t)

# 결과 출력
print(interpolated_train_data_t[['ws10_deg', 'ws10_deg_sin', 'ws10_deg_cos']])
# Out:
#         ws10_deg  ws10_deg_sin  ws10_deg_cos
# 0            0.0      0.000000      1.000000
# 1            0.0      0.000000      1.000000
# 2            0.0      0.000000      1.000000
# 3           27.8      0.466387      0.884581
# 4           59.7      0.863396      0.504528
# ...          ...           ...           ...
# 157817     305.3     -0.816138      0.577858
# 157818     293.8     -0.914960      0.403545
# 157819     274.2     -0.997314      0.073238
# 157820     270.3     -0.999986      0.005236
# 157821     254.8     -0.965016     -0.262189
#
# [3156459 rows x 3 columns]

# %%
# 풍향을 주기적인 특성으로 변환하는 함수
def transform_wind_direction(df):
    df['ws10_deg_sin'] = np.sin(np.deg2rad(df['ws10_deg']))
    df['ws10_deg_cos'] = np.cos(np.deg2rad(df['ws10_deg']))
    return df

# 데이터프레임에 변환 적용
interpolated_test_data_t = transform_wind_direction(interpolated_test_data_t)

# 결과 출력
print(interpolated_test_data_t[['ws10_deg', 'ws10_deg_sin', 'ws10_deg_cos']])
# Out:
#        ws10_deg  ws10_deg_sin  ws10_deg_cos
# 0         329.5     -0.507538      0.861629
# 1         321.8     -0.618408      0.785857
# 2           0.4      0.006981      0.999976
# 3         323.6     -0.593419      0.804894
# 4         208.4     -0.475624     -0.879649
# ...         ...           ...           ...
# 52555     338.8     -0.361625      0.932324
# 52556     335.2     -0.419452      0.907777
# 52557     337.1     -0.389124      0.921185
# 52558     322.0     -0.615661      0.788011
# 52559      33.6      0.553392      0.832921
#
# [262800 rows x 3 columns]

# %% [markdown]
# # 축약

# %%
# 필요 없는 열 제거
columns_to_drop = ['datetime', 'year', 'month', 'day', 'hour', 'minute', 'seconds_in_day', 'seconds_in_year','dew_point_minus_ta', 'dew_point','re','ws10_deg']

train_data_final_drop = interpolated_train_data_t.drop(columns=columns_to_drop)
# 필요 없는 열 제거
test_data_final_drop = interpolated_test_data_t.drop(columns=columns_to_drop)

# %%
train_data_final_drop
# Out:
#        stn_id  ws10_ms   ta    hm  sun10   ts     vis1  class  time_sin  \
# 0          AA      0.0 -6.4  38.9    0.0 -2.8  20000.0    4.0  0.043619
# 1          AA      0.0 -6.3  37.9    0.0 -2.7  20000.0    4.0  0.087156
# 2          AA      0.0 -6.3  40.0    0.0 -2.6  20000.0    4.0  0.130526
# 3          AA      0.4 -6.2  39.5    0.0 -2.6  20000.0    4.0  0.173648
# 4          AA      0.5 -6.1  39.8    0.0 -2.5  20000.0    4.0  0.216440
# ...       ...      ...  ...   ...    ...  ...      ...    ...       ...
# 157817     EC      7.7  2.5  50.2    0.0 -0.9  20000.0    4.0 -0.216440
# 157818     EC      5.7  2.3  50.1    0.0 -1.3  20000.0    4.0 -0.173648
# 157819     EC      4.9  2.2  51.0    0.0 -1.4  20000.0    4.0 -0.130526
# 157820     EC      4.6  2.1  51.7    0.0 -1.6  20000.0    4.0 -0.087156
# 157821     EC      4.1  2.1  53.3    0.0 -1.7  20000.0    4.0 -0.043619
#
#         time_cos  yearly_time_sin  yearly_time_cos  Temp_Diff  \
# 0       0.999048         0.000120              1.0       -3.6
# 1       0.996195         0.000239              1.0       -3.6
# 2       0.991445         0.000359              1.0       -3.7
# 3       0.984808         0.000478              1.0       -3.6
# 4       0.976296         0.000598              1.0       -3.6
# ...          ...              ...              ...        ...
# 157817  0.976296        -0.000598              1.0        3.4
# 157818  0.984808        -0.000478              1.0        3.6
# 157819  0.991445        -0.000359              1.0        3.6
# 157820  0.996195        -0.000239              1.0        3.7
# 157821  0.999048        -0.000120              1.0        3.8
#
#         sqrt_rounded_diff  Fog_Likelihood_Index  ws10_deg_sin  ws10_deg_cos
# 0                3.420526           -140.040000      0.000000      1.000000
# 1                3.478505           -136.440000      0.000000      1.000000
# 2                3.376389           -148.000000      0.000000      1.000000
# 3                3.405877           -101.571429      0.466387      0.884581
# 4                3.391165            -95.520000      0.863396      0.504528
# ...                   ...                   ...           ...           ...
# 157817           3.049590             19.618391     -0.816138      0.577858
# 157818           3.049590             26.919403     -0.914960      0.403545
# 157819           3.016621             31.118644     -0.997314      0.073238
# 157820           2.983287             34.158929     -0.999986      0.005236
# 157821           2.915476             39.713725     -0.965016     -0.262189
#
# [3156459 rows x 17 columns]

# %%
import pandas as pd



# 검증용 데이터로 사용할 지역 목록
val_regions = ['AA', 'EC', 'DA', 'BB']

# train_df_A3_val과 train_df_A3_train 데이터프레임 생성
train_df_A3_val = train_data_final_drop[train_data_final_drop['stn_id'].isin(val_regions)]
train_df_A3_train = train_data_final_drop[~train_data_final_drop['stn_id'].isin(val_regions)]

# %%
train_df_A3_train
# Out:
#       stn_id  ws10_deg  ws10_ms   ta    hm  sun10   ts  time_sin  time_cos  \
# 0         AI     329.5      0.6 -2.5  87.5    0.0 -1.6  0.000000  1.000000
# 1         AI     321.8      1.2 -2.5  88.2    0.0 -1.6  0.043619  0.999048
# 2         AI       0.4      0.4 -2.5  88.6    0.0 -1.7  0.087156  0.996195
# 3         AI     323.6      0.7 -2.6  88.7    0.0 -1.6  0.130526  0.991445
# 4         AI     208.4      0.2 -2.6  89.0    0.0 -1.6  0.173648  0.984808
# ...      ...       ...      ...  ...   ...    ...  ...       ...       ...
# 52555     ED     338.8      6.1  4.5  71.3    0.0  1.9 -0.216440  0.976296
# 52556     ED     335.2      5.8  4.6  71.4    0.0  1.9 -0.173648  0.984808
# 52557     ED     337.1      5.3  4.5  72.1    0.0  1.8 -0.130526  0.991445
# 52558     ED     322.0      3.7  4.3  72.5    0.0  1.4 -0.087156  0.996195
# 52559     ED      33.6      2.8  4.3  73.7    0.0  1.3 -0.043619  0.999048
#
#        yearly_time_sin  yearly_time_cos  Temp_Diff  sqrt_rounded_diff  \
# 0             0.000000         1.000000       -0.9           1.341641
# 1             0.000120         1.000000       -0.9           1.303840
# 2             0.000239         1.000000       -0.8           1.264911
# 3             0.000359         1.000000       -1.0           1.264911
# 4             0.000478         1.000000       -1.0           1.264911
# ...                ...              ...        ...                ...
# 52555         0.016616         0.999862        2.6           2.167948
# 52556         0.016735         0.999860        2.7           2.167948
# 52557         0.016855         0.999858        2.7           2.144761
# 52558         0.016974         0.999856        2.9           2.121320
# 52559         0.017094         0.999854        3.0           2.073644
#
#        Fog_Likelihood_Index  ws10_deg_sin  ws10_deg_cos
# 0                -49.218750     -0.507538      0.861629
# 1                -36.081818     -0.618408      0.785857
# 2                -50.628571      0.006981      0.999976
# 3                -52.176471     -0.593419      0.804894
# 4                -74.166667     -0.475624     -0.879649
# ...                     ...           ...           ...
# 52555             26.109859     -0.361625      0.932324
# 52556             28.350000     -0.419452      0.907777
# 52557             30.900000     -0.389124      0.921185
# 52558             44.734043     -0.615661      0.788011
# 52559             58.184211      0.553392      0.832921
#
# [262800 rows x 16 columns]

# %% [markdown]
# #XGBOOST

# %%
train_df_A3_train = train_df_A3_train.drop('stn_id', axis=1)
train_df_A3_val = train_df_A3_val.drop('stn_id', axis=1)

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix

# 특징과 라벨 분리 (훈련 데이터)
X_train_final = train_df_A3_train.drop(['class', 'vis1'], axis=1)
y_train_final = train_df_A3_train['class']

X_val = train_df_A3_val.drop(['class', 'vis1'], axis=1)
y_val = train_df_A3_val['class']

# 오버샘플링 적용 전 클래스 비율 확인
print("Original class distribution in training set:")
print(y_train_final.value_counts(normalize=True))

# 각 클래스의 샘플 개수 확인
class_counts = y_train_final.value_counts()

# 샘플링 전략 설정
sampling_strategy = {
    1: int(class_counts[1] * 23.0),  # 클래스 1의 목표 샘플 수
    2: int(class_counts[2] * 17.0),  # 클래스 2의 목표 샘플 수
    3: int(class_counts[3] * 17.0),  # 클래스 3의 목표 샘플 수
    4: class_counts[4]  # 클래스 4는 원래 개수 유지
}

# SMOTE 적용
smote = SMOTE(sampling_strategy=sampling_strategy, random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_final, y_train_final)

# 오버샘플링 적용 후 클래스 비율 확인
print("Class distribution after SMOTE in training set:")
print(pd.Series(y_train_smote).value_counts(normalize=True))

# 데이터셋 크기 확인
print('훈련 데이터셋 크기 (SMOTE 적용 후):', X_train_smote.shape, y_train_smote.shape)
print('검증 데이터셋 크기:', X_val.shape, y_val.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a78ebe52aec> in <cell line: 8>()
#       6
#       7 # 특징과 라벨 분리 (훈련 데이터)
# ----> 8 X_train_final = train_df_A3_train.drop(['class', 'vis1'], axis=1)
#       9 y_train_final = train_df_A3_train['class']
#      10
#
# NameError: name 'train_df_A3_train' is not defined

# %%
# 클래스 라벨을 0부터 시작하도록 변환 (라벨 값이 1부터 시작하는 경우)
y_train_smote = y_train_smote - y_train_smote.min()
y_val = y_val - y_val.min()

# 라벨 값이 0부터 num_class-1 사이에 있는지 확인
assert y_train_smote.min() >= 0 and y_train_smote.max() < 4, "Train labels must be in the range [0, num_class)."
assert y_val.min() >= 0 and y_val.max() < 4, "Validation labels must be in the range [0, num_class)."

# %%
# XGBoost 모델 학습
dtrain = xgb.DMatrix(X_train_smote, label=y_train_smote)
dval = xgb.DMatrix(X_val, label=y_val)

params = {
    'objective': 'multi:softprob',
    'num_class': 4,  # 클래스의 수
    'eval_metric': 'mlogloss',
    'eta': 0.1,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
}

# 모델 훈련
evals = [(dtrain, 'train'), (dval, 'eval')]
bst = xgb.train(params, dtrain, num_boost_round=100, evals=evals, early_stopping_rounds=10)

# 검증 데이터에 대한 예측
y_pred = bst.predict(dval)
y_pred_classes = np.argmax(y_pred, axis=1)

# 혼동 행렬 출력
conf_matrix = confusion_matrix(y_val, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

# %%
# 클래스 가중치 계산
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train_smote), y=y_train_smote)
class_weights = {cls: weight for cls, weight in zip(np.unique(y_train_smote), class_weights)}

# 가중치 부여
weights = np.array([class_weights[label] for label in y_train_smote])

# DMatrix 생성
dtrain = xgb.DMatrix(X_train_smote, label=y_train_smote, weight=weights)
dval = xgb.DMatrix(X_val, label=y_val)

# %%
# XGBoost 모델 학습
param = {
    'objective': 'multi:softmax',
    'num_class': 4,
    'eval_metric': 'mlogloss',
    'eta': 0.3,
    'max_depth': 6,
    'seed': 42
}

num_round = 1000
evallist = [(dval, 'eval'), (dtrain, 'train')]
bst = xgb.train(param, dtrain, num_round, evallist, early_stopping_rounds=10)

# 검증 데이터에 대한 예측
y_val_pred = bst.predict(dval)
# Out:
# [0]	eval-mlogloss:1.00736	train-mlogloss:1.23716
# [1]	eval-mlogloss:0.80213	train-mlogloss:1.14669
# [2]	eval-mlogloss:0.66366	train-mlogloss:1.08411
# [3]	eval-mlogloss:0.56705	train-mlogloss:1.03559
# [4]	eval-mlogloss:0.50006	train-mlogloss:1.00000
# [5]	eval-mlogloss:0.44986	train-mlogloss:0.97186
# [6]	eval-mlogloss:0.41315	train-mlogloss:0.94905
# [7]	eval-mlogloss:0.38507	train-mlogloss:0.93028
# [8]	eval-mlogloss:0.36451	train-mlogloss:0.91628
# [9]	eval-mlogloss:0.34616	train-mlogloss:0.90085
# [10]	eval-mlogloss:0.32837	train-mlogloss:0.88741
# [11]	eval-mlogloss:0.31599	train-mlogloss:0.87647
# [12]	eval-mlogloss:0.30454	train-mlogloss:0.86693
# [13]	eval-mlogloss:0.29469	train-mlogloss:0.85840
# [14]	eval-mlogloss:0.28562	train-mlogloss:0.85006
# [15]	eval-mlogloss:0.27881	train-mlogloss:0.84192
# [16]	eval-mlogloss:0.27041	train-mlogloss:0.83396
# [17]	eval-mlogloss:0.26511	train-mlogloss:0.82745
# [18]	eval-mlogloss:0.25633	train-mlogloss:0.82102
# [19]	eval-mlogloss:0.25181	train-mlogloss:0.81543
# [20]	eval-mlogloss:0.24646	train-mlogloss:0.80899
# [21]	eval-mlogloss:0.24017	train-mlogloss:0.80139
# [22]	eval-mlogloss:0.23551	train-mlogloss:0.79329
# [23]	eval-mlogloss:0.23360	train-mlogloss:0.78983
# [24]	eval-mlogloss:0.22768	train-mlogloss:0.78307
# [25]	eval-mlogloss:0.22218	train-mlogloss:0.77819
# [26]	eval-mlogloss:0.21707	train-mlogloss:0.77339
# [27]	eval-mlogloss:0.21508	train-mlogloss:0.76986
# [28]	eval-mlogloss:0.21276	train-mlogloss:0.76541
# [29]	eval-mlogloss:0.21044	train-mlogloss:0.76113
# [30]	eval-mlogloss:0.20485	train-mlogloss:0.75552
# [31]	eval-mlogloss:0.20115	train-mlogloss:0.75137
# [32]	eval-mlogloss:0.19764	train-mlogloss:0.74727
# [33]	eval-mlogloss:0.19453	train-mlogloss:0.74269
# [34]	eval-mlogloss:0.19157	train-mlogloss:0.73782
# [35]	eval-mlogloss:0.18874	train-mlogloss:0.73250
# [36]	eval-mlogloss:0.18534	train-mlogloss:0.72817
# [37]	eval-mlogloss:0.18146	train-mlogloss:0.72515
# [38]	eval-mlogloss:0.18085	train-mlogloss:0.72165
# [39]	eval-mlogloss:0.17914	train-mlogloss:0.71888
# [40]	eval-mlogloss:0.17719	train-mlogloss:0.71456
# [41]	eval-mlogloss:0.17372	train-mlogloss:0.70942
# [42]	eval-mlogloss:0.17173	train-mlogloss:0.70530
# [43]	eval-mlogloss:0.17002	train-mlogloss:0.70183
# [44]	eval-mlogloss:0.16777	train-mlogloss:0.69867
# [45]	eval-mlogloss:0.16548	train-mlogloss:0.69485
# [46]	eval-mlogloss:0.16372	train-mlogloss:0.69137
# [47]	eval-mlogloss:0.16263	train-mlogloss:0.68829
# [48]	eval-mlogloss:0.16029	train-mlogloss:0.68538
# [49]	eval-mlogloss:0.15867	train-mlogloss:0.68282
# [50]	eval-mlogloss:0.15678	train-mlogloss:0.67958
# [51]	eval-mlogloss:0.15556	train-mlogloss:0.67673
# [52]	eval-mlogloss:0.15400	train-mlogloss:0.67446
# [53]	eval-mlogloss:0.15279	train-mlogloss:0.67143
# [54]	eval-mlogloss:0.15152	train-mlogloss:0.66881
# [55]	eval-mlogloss:0.14994	train-mlogloss:0.66631
# [56]	eval-mlogloss:0.14836	train-mlogloss:0.66384
# [57]	eval-mlogloss:0.14599	train-mlogloss:0.66051
# [58]	eval-mlogloss:0.14476	train-mlogloss:0.65859
# [59]	eval-mlogloss:0.14371	train-mlogloss:0.65693
# [60]	eval-mlogloss:0.14301	train-mlogloss:0.65400
# [61]	eval-mlogloss:0.14190	train-mlogloss:0.65249
# [62]	eval-mlogloss:0.14053	train-mlogloss:0.64938
# [63]	eval-mlogloss:0.13981	train-mlogloss:0.64700
# [64]	eval-mlogloss:0.13881	train-mlogloss:0.64477
# [65]	eval-mlogloss:0.13793	train-mlogloss:0.64182
# [66]	eval-mlogloss:0.13764	train-mlogloss:0.63983
# [67]	eval-mlogloss:0.13560	train-mlogloss:0.63663
# [68]	eval-mlogloss:0.13492	train-mlogloss:0.63430
# [69]	eval-mlogloss:0.13368	train-mlogloss:0.63131
# [70]	eval-mlogloss:0.13317	train-mlogloss:0.62897
# [71]	eval-mlogloss:0.13222	train-mlogloss:0.62711
# [72]	eval-mlogloss:0.13112	train-mlogloss:0.62363
# [73]	eval-mlogloss:0.13021	train-mlogloss:0.62123
# [74]	eval-mlogloss:0.12883	train-mlogloss:0.61841
# [75]	eval-mlogloss:0.12831	train-mlogloss:0.61699
# [76]	eval-mlogloss:0.12743	train-mlogloss:0.61470
# [77]	eval-mlogloss:0.12696	train-mlogloss:0.61272
# [78]	eval-mlogloss:0.12594	train-mlogloss:0.61096
# [79]	eval-mlogloss:0.12468	train-mlogloss:0.60940
# [80]	eval-mlogloss:0.12400	train-mlogloss:0.60746
# [81]	eval-mlogloss:0.12345	train-mlogloss:0.60556
# [82]	eval-mlogloss:0.12296	train-mlogloss:0.60345
# [83]	eval-mlogloss:0.12222	train-mlogloss:0.60061
# [84]	eval-mlogloss:0.12182	train-mlogloss:0.59836
# [85]	eval-mlogloss:0.12114	train-mlogloss:0.59561
# [86]	eval-mlogloss:0.12039	train-mlogloss:0.59308
# [87]	eval-mlogloss:0.11972	train-mlogloss:0.59104
# [88]	eval-mlogloss:0.11934	train-mlogloss:0.58962
# [89]	eval-mlogloss:0.11861	train-mlogloss:0.58854
# [90]	eval-mlogloss:0.11822	train-mlogloss:0.58718
# [91]	eval-mlogloss:0.11776	train-mlogloss:0.58585
# [92]	eval-mlogloss:0.11687	train-mlogloss:0.58387
# [93]	eval-mlogloss:0.11621	train-mlogloss:0.58193
# [94]	eval-mlogloss:0.11521	train-mlogloss:0.58004
# [95]	eval-mlogloss:0.11478	train-mlogloss:0.57842
# [96]	eval-mlogloss:0.11471	train-mlogloss:0.57595
# [97]	eval-mlogloss:0.11422	train-mlogloss:0.57416
# [98]	eval-mlogloss:0.11360	train-mlogloss:0.57336
# [99]	eval-mlogloss:0.11326	train-mlogloss:0.57161
# [100]	eval-mlogloss:0.11272	train-mlogloss:0.57032
# [101]	eval-mlogloss:0.11180	train-mlogloss:0.56801
# [102]	eval-mlogloss:0.11137	train-mlogloss:0.56626
# [103]	eval-mlogloss:0.11091	train-mlogloss:0.56460
# [104]	eval-mlogloss:0.11045	train-mlogloss:0.56277
# [105]	eval-mlogloss:0.10993	train-mlogloss:0.56096
# [106]	eval-mlogloss:0.10919	train-mlogloss:0.55950
# [107]	eval-mlogloss:0.10877	train-mlogloss:0.55842
# [108]	eval-mlogloss:0.10834	train-mlogloss:0.55655
# [109]	eval-mlogloss:0.10809	train-mlogloss:0.55504
# [110]	eval-mlogloss:0.10758	train-mlogloss:0.55385
# [111]	eval-mlogloss:0.10706	train-mlogloss:0.55235
# [112]	eval-mlogloss:0.10655	train-mlogloss:0.55053
# [113]	eval-mlogloss:0.10596	train-mlogloss:0.54878
# [114]	eval-mlogloss:0.10574	train-mlogloss:0.54759
# [115]	eval-mlogloss:0.10530	train-mlogloss:0.54640
# [116]	eval-mlogloss:0.10517	train-mlogloss:0.54467
# [117]	eval-mlogloss:0.10458	train-mlogloss:0.54275
# [118]	eval-mlogloss:0.10447	train-mlogloss:0.54077
# [119]	eval-mlogloss:0.10398	train-mlogloss:0.53876
# [120]	eval-mlogloss:0.10374	train-mlogloss:0.53713
# [121]	eval-mlogloss:0.10334	train-mlogloss:0.53495
# [122]	eval-mlogloss:0.10267	train-mlogloss:0.53338
# [123]	eval-mlogloss:0.10225	train-mlogloss:0.53192
# [124]	eval-mlogloss:0.10189	train-mlogloss:0.52989
# [125]	eval-mlogloss:0.10161	train-mlogloss:0.52781
# [126]	eval-mlogloss:0.10107	train-mlogloss:0.52590
# [127]	eval-mlogloss:0.10051	train-mlogloss:0.52391
# [128]	eval-mlogloss:0.10016	train-mlogloss:0.52235
# [129]	eval-mlogloss:0.09984	train-mlogloss:0.52101
# [130]	eval-mlogloss:0.09964	train-mlogloss:0.51974
# [131]	eval-mlogloss:0.09939	train-mlogloss:0.51823
# [132]	eval-mlogloss:0.09908	train-mlogloss:0.51684
# [133]	eval-mlogloss:0.09881	train-mlogloss:0.51552
# [134]	eval-mlogloss:0.09856	train-mlogloss:0.51400
# [135]	eval-mlogloss:0.09820	train-mlogloss:0.51249
# [136]	eval-mlogloss:0.09814	train-mlogloss:0.51098
# [137]	eval-mlogloss:0.09743	train-mlogloss:0.50912
# [138]	eval-mlogloss:0.09704	train-mlogloss:0.50788
# [139]	eval-mlogloss:0.09674	train-mlogloss:0.50683
# [140]	eval-mlogloss:0.09654	train-mlogloss:0.50550
# [141]	eval-mlogloss:0.09637	train-mlogloss:0.50390
# [142]	eval-mlogloss:0.09609	train-mlogloss:0.50237
# [143]	eval-mlogloss:0.09588	train-mlogloss:0.50115
# [144]	eval-mlogloss:0.09570	train-mlogloss:0.50000
# [145]	eval-mlogloss:0.09541	train-mlogloss:0.49917
# [146]	eval-mlogloss:0.09525	train-mlogloss:0.49798
# [147]	eval-mlogloss:0.09519	train-mlogloss:0.49686
# [148]	eval-mlogloss:0.09468	train-mlogloss:0.49560
# [149]	eval-mlogloss:0.09461	train-mlogloss:0.49426
# [150]	eval-mlogloss:0.09448	train-mlogloss:0.49324
# [151]	eval-mlogloss:0.09427	train-mlogloss:0.49221
# [152]	eval-mlogloss:0.09401	train-mlogloss:0.49102
# [153]	eval-mlogloss:0.09375	train-mlogloss:0.49009
# [154]	eval-mlogloss:0.09351	train-mlogloss:0.48898
# [155]	eval-mlogloss:0.09328	train-mlogloss:0.48789
# [156]	eval-mlogloss:0.09303	train-mlogloss:0.48685
# [157]	eval-mlogloss:0.09276	train-mlogloss:0.48550
# [158]	eval-mlogloss:0.09253	train-mlogloss:0.48418
# [159]	eval-mlogloss:0.09234	train-mlogloss:0.48275
# [160]	eval-mlogloss:0.09201	train-mlogloss:0.48150
# [161]	eval-mlogloss:0.09184	train-mlogloss:0.48007
# [162]	eval-mlogloss:0.09173	train-mlogloss:0.47907
# [163]	eval-mlogloss:0.09156	train-mlogloss:0.47801
# [164]	eval-mlogloss:0.09148	train-mlogloss:0.47669
# [165]	eval-mlogloss:0.09116	train-mlogloss:0.47549
# [166]	eval-mlogloss:0.09091	train-mlogloss:0.47406
# [167]	eval-mlogloss:0.09066	train-mlogloss:0.47312
# [168]	eval-mlogloss:0.09046	train-mlogloss:0.47230
# [169]	eval-mlogloss:0.09019	train-mlogloss:0.47073
# [170]	eval-mlogloss:0.08993	train-mlogloss:0.46950
# [171]	eval-mlogloss:0.08969	train-mlogloss:0.46824
# [172]	eval-mlogloss:0.08968	train-mlogloss:0.46715
# [173]	eval-mlogloss:0.08937	train-mlogloss:0.46627
# [174]	eval-mlogloss:0.08935	train-mlogloss:0.46558
# [175]	eval-mlogloss:0.08907	train-mlogloss:0.46440
# [176]	eval-mlogloss:0.08885	train-mlogloss:0.46333
# [177]	eval-mlogloss:0.08855	train-mlogloss:0.46224
# [178]	eval-mlogloss:0.08852	train-mlogloss:0.46109
# [179]	eval-mlogloss:0.08826	train-mlogloss:0.46035
# [180]	eval-mlogloss:0.08808	train-mlogloss:0.45886
# [181]	eval-mlogloss:0.08797	train-mlogloss:0.45782
# [182]	eval-mlogloss:0.08776	train-mlogloss:0.45666
# [183]	eval-mlogloss:0.08763	train-mlogloss:0.45599
# [184]	eval-mlogloss:0.08748	train-mlogloss:0.45490
# [185]	eval-mlogloss:0.08734	train-mlogloss:0.45359
# [186]	eval-mlogloss:0.08725	train-mlogloss:0.45276
# [187]	eval-mlogloss:0.08712	train-mlogloss:0.45161
# [188]	eval-mlogloss:0.08696	train-mlogloss:0.45088
# [189]	eval-mlogloss:0.08687	train-mlogloss:0.44954
# [190]	eval-mlogloss:0.08668	train-mlogloss:0.44879
# [191]	eval-mlogloss:0.08660	train-mlogloss:0.44813
# [192]	eval-mlogloss:0.08642	train-mlogloss:0.44725
# [193]	eval-mlogloss:0.08621	train-mlogloss:0.44640
# [194]	eval-mlogloss:0.08613	train-mlogloss:0.44538
# [195]	eval-mlogloss:0.08587	train-mlogloss:0.44413
# [196]	eval-mlogloss:0.08569	train-mlogloss:0.44304
# [197]	eval-mlogloss:0.08565	train-mlogloss:0.44212
# [198]	eval-mlogloss:0.08556	train-mlogloss:0.44136
# [199]	eval-mlogloss:0.08547	train-mlogloss:0.44081
# [200]	eval-mlogloss:0.08539	train-mlogloss:0.43998
# [201]	eval-mlogloss:0.08515	train-mlogloss:0.43922
# [202]	eval-mlogloss:0.08501	train-mlogloss:0.43850
# [203]	eval-mlogloss:0.08483	train-mlogloss:0.43736
# [204]	eval-mlogloss:0.08456	train-mlogloss:0.43603
# [205]	eval-mlogloss:0.08438	train-mlogloss:0.43513
# [206]	eval-mlogloss:0.08425	train-mlogloss:0.43338
# [207]	eval-mlogloss:0.08418	train-mlogloss:0.43225
# [208]	eval-mlogloss:0.08396	train-mlogloss:0.43112
# [209]	eval-mlogloss:0.08386	train-mlogloss:0.43002
# [210]	eval-mlogloss:0.08378	train-mlogloss:0.42871
# [211]	eval-mlogloss:0.08369	train-mlogloss:0.42765
# [212]	eval-mlogloss:0.08356	train-mlogloss:0.42642
# [213]	eval-mlogloss:0.08350	train-mlogloss:0.42528
# [214]	eval-mlogloss:0.08336	train-mlogloss:0.42452
# [215]	eval-mlogloss:0.08326	train-mlogloss:0.42335
# [216]	eval-mlogloss:0.08321	train-mlogloss:0.42240
# [217]	eval-mlogloss:0.08300	train-mlogloss:0.42129
# [218]	eval-mlogloss:0.08292	train-mlogloss:0.42035
# [219]	eval-mlogloss:0.08284	train-mlogloss:0.41963
# [220]	eval-mlogloss:0.08270	train-mlogloss:0.41862
# [221]	eval-mlogloss:0.08258	train-mlogloss:0.41761
# [222]	eval-mlogloss:0.08250	train-mlogloss:0.41688
# [223]	eval-mlogloss:0.08239	train-mlogloss:0.41628
# [224]	eval-mlogloss:0.08235	train-mlogloss:0.41567
# [225]	eval-mlogloss:0.08227	train-mlogloss:0.41480
# [226]	eval-mlogloss:0.08221	train-mlogloss:0.41403
# [227]	eval-mlogloss:0.08210	train-mlogloss:0.41297
# [228]	eval-mlogloss:0.08200	train-mlogloss:0.41208
# [229]	eval-mlogloss:0.08195	train-mlogloss:0.41133
# [230]	eval-mlogloss:0.08192	train-mlogloss:0.41018
# [231]	eval-mlogloss:0.08185	train-mlogloss:0.40962
# [232]	eval-mlogloss:0.08170	train-mlogloss:0.40895
# [233]	eval-mlogloss:0.08159	train-mlogloss:0.40830
# [234]	eval-mlogloss:0.08153	train-mlogloss:0.40717
# [235]	eval-mlogloss:0.08143	train-mlogloss:0.40660
# [236]	eval-mlogloss:0.08131	train-mlogloss:0.40578
# [237]	eval-mlogloss:0.08118	train-mlogloss:0.40514
# [238]	eval-mlogloss:0.08108	train-mlogloss:0.40460
# [239]	eval-mlogloss:0.08092	train-mlogloss:0.40354
# [240]	eval-mlogloss:0.08087	train-mlogloss:0.40316
# [241]	eval-mlogloss:0.08078	train-mlogloss:0.40268
# [242]	eval-mlogloss:0.08072	train-mlogloss:0.40193
# [243]	eval-mlogloss:0.08060	train-mlogloss:0.40101
# [244]	eval-mlogloss:0.08055	train-mlogloss:0.40046
# [245]	eval-mlogloss:0.08046	train-mlogloss:0.39960
# [246]	eval-mlogloss:0.08044	train-mlogloss:0.39893
# [247]	eval-mlogloss:0.08029	train-mlogloss:0.39797
# [248]	eval-mlogloss:0.08030	train-mlogloss:0.39735
# [249]	eval-mlogloss:0.08027	train-mlogloss:0.39650
# [250]	eval-mlogloss:0.08031	train-mlogloss:0.39573
# [251]	eval-mlogloss:0.08026	train-mlogloss:0.39503
# [252]	eval-mlogloss:0.08018	train-mlogloss:0.39419
# [253]	eval-mlogloss:0.08012	train-mlogloss:0.39328
# [254]	eval-mlogloss:0.08011	train-mlogloss:0.39242
# [255]	eval-mlogloss:0.08004	train-mlogloss:0.39162
# [256]	eval-mlogloss:0.07996	train-mlogloss:0.39083
# [257]	eval-mlogloss:0.07986	train-mlogloss:0.39003
# [258]	eval-mlogloss:0.07978	train-mlogloss:0.38927
# [259]	eval-mlogloss:0.07978	train-mlogloss:0.38876
# [260]	eval-mlogloss:0.07985	train-mlogloss:0.38800
# [261]	eval-mlogloss:0.07975	train-mlogloss:0.38761
# [262]	eval-mlogloss:0.07966	train-mlogloss:0.38687
# [263]	eval-mlogloss:0.07966	train-mlogloss:0.38638
# [264]	eval-mlogloss:0.07957	train-mlogloss:0.38519
# [265]	eval-mlogloss:0.07944	train-mlogloss:0.38446
# [266]	eval-mlogloss:0.07947	train-mlogloss:0.38376
# [267]	eval-mlogloss:0.07939	train-mlogloss:0.38309
# [268]	eval-mlogloss:0.07931	train-mlogloss:0.38242
# [269]	eval-mlogloss:0.07921	train-mlogloss:0.38155
# [270]	eval-mlogloss:0.07920	train-mlogloss:0.38095
# [271]	eval-mlogloss:0.07913	train-mlogloss:0.37997
# [272]	eval-mlogloss:0.07906	train-mlogloss:0.37937
# [273]	eval-mlogloss:0.07906	train-mlogloss:0.37867
# [274]	eval-mlogloss:0.07896	train-mlogloss:0.37768
# [275]	eval-mlogloss:0.07888	train-mlogloss:0.37694
# [276]	eval-mlogloss:0.07883	train-mlogloss:0.37613
# [277]	eval-mlogloss:0.07885	train-mlogloss:0.37563
# [278]	eval-mlogloss:0.07864	train-mlogloss:0.37503
# [279]	eval-mlogloss:0.07854	train-mlogloss:0.37427
# [280]	eval-mlogloss:0.07846	train-mlogloss:0.37376
# [281]	eval-mlogloss:0.07836	train-mlogloss:0.37309
# [282]	eval-mlogloss:0.07827	train-mlogloss:0.37197
# [283]	eval-mlogloss:0.07819	train-mlogloss:0.37136
# [284]	eval-mlogloss:0.07813	train-mlogloss:0.37046
# [285]	eval-mlogloss:0.07797	train-mlogloss:0.36987
# [286]	eval-mlogloss:0.07798	train-mlogloss:0.36908
# [287]	eval-mlogloss:0.07792	train-mlogloss:0.36846
# [288]	eval-mlogloss:0.07787	train-mlogloss:0.36775
# [289]	eval-mlogloss:0.07788	train-mlogloss:0.36707
# [290]	eval-mlogloss:0.07786	train-mlogloss:0.36659
# [291]	eval-mlogloss:0.07777	train-mlogloss:0.36589
# [292]	eval-mlogloss:0.07769	train-mlogloss:0.36524
# [293]	eval-mlogloss:0.07763	train-mlogloss:0.36469
# [294]	eval-mlogloss:0.07764	train-mlogloss:0.36404
# [295]	eval-mlogloss:0.07759	train-mlogloss:0.36341
# [296]	eval-mlogloss:0.07751	train-mlogloss:0.36284
# [297]	eval-mlogloss:0.07750	train-mlogloss:0.36218
# [298]	eval-mlogloss:0.07746	train-mlogloss:0.36165
# [299]	eval-mlogloss:0.07733	train-mlogloss:0.36126
# [300]	eval-mlogloss:0.07730	train-mlogloss:0.36064
# [301]	eval-mlogloss:0.07726	train-mlogloss:0.36020
# [302]	eval-mlogloss:0.07725	train-mlogloss:0.35960
# [303]	eval-mlogloss:0.07723	train-mlogloss:0.35908
# [304]	eval-mlogloss:0.07719	train-mlogloss:0.35848
# [305]	eval-mlogloss:0.07722	train-mlogloss:0.35824
# [306]	eval-mlogloss:0.07722	train-mlogloss:0.35780
# [307]	eval-mlogloss:0.07722	train-mlogloss:0.35730
# [308]	eval-mlogloss:0.07717	train-mlogloss:0.35675
# [309]	eval-mlogloss:0.07713	train-mlogloss:0.35590
# [310]	eval-mlogloss:0.07709	train-mlogloss:0.35530
# [311]	eval-mlogloss:0.07702	train-mlogloss:0.35464
# [312]	eval-mlogloss:0.07705	train-mlogloss:0.35397
# [313]	eval-mlogloss:0.07702	train-mlogloss:0.35354
# [314]	eval-mlogloss:0.07699	train-mlogloss:0.35280
# [315]	eval-mlogloss:0.07696	train-mlogloss:0.35209
# [316]	eval-mlogloss:0.07690	train-mlogloss:0.35144
# [317]	eval-mlogloss:0.07685	train-mlogloss:0.35073
# [318]	eval-mlogloss:0.07682	train-mlogloss:0.35024
# [319]	eval-mlogloss:0.07672	train-mlogloss:0.34952
# [320]	eval-mlogloss:0.07669	train-mlogloss:0.34911
# [321]	eval-mlogloss:0.07664	train-mlogloss:0.34851
# [322]	eval-mlogloss:0.07660	train-mlogloss:0.34792
# [323]	eval-mlogloss:0.07654	train-mlogloss:0.34723
# [324]	eval-mlogloss:0.07652	train-mlogloss:0.34633
# [325]	eval-mlogloss:0.07655	train-mlogloss:0.34564
# [326]	eval-mlogloss:0.07657	train-mlogloss:0.34514
# [327]	eval-mlogloss:0.07652	train-mlogloss:0.34447
# [328]	eval-mlogloss:0.07649	train-mlogloss:0.34404
# [329]	eval-mlogloss:0.07640	train-mlogloss:0.34338
# [330]	eval-mlogloss:0.07635	train-mlogloss:0.34270
# [331]	eval-mlogloss:0.07633	train-mlogloss:0.34196
# [332]	eval-mlogloss:0.07629	train-mlogloss:0.34147
# [333]	eval-mlogloss:0.07621	train-mlogloss:0.34115
# [334]	eval-mlogloss:0.07622	train-mlogloss:0.34055
# [335]	eval-mlogloss:0.07620	train-mlogloss:0.34007
# [336]	eval-mlogloss:0.07618	train-mlogloss:0.33945
# [337]	eval-mlogloss:0.07611	train-mlogloss:0.33891
# [338]	eval-mlogloss:0.07611	train-mlogloss:0.33823
# [339]	eval-mlogloss:0.07608	train-mlogloss:0.33765
# [340]	eval-mlogloss:0.07604	train-mlogloss:0.33726
# [341]	eval-mlogloss:0.07607	train-mlogloss:0.33683
# [342]	eval-mlogloss:0.07606	train-mlogloss:0.33648
# [343]	eval-mlogloss:0.07604	train-mlogloss:0.33580
# [344]	eval-mlogloss:0.07598	train-mlogloss:0.33504
# [345]	eval-mlogloss:0.07594	train-mlogloss:0.33437
# [346]	eval-mlogloss:0.07590	train-mlogloss:0.33391
# [347]	eval-mlogloss:0.07592	train-mlogloss:0.33348
# [348]	eval-mlogloss:0.07589	train-mlogloss:0.33284
# [349]	eval-mlogloss:0.07582	train-mlogloss:0.33236
# [350]	eval-mlogloss:0.07581	train-mlogloss:0.33173
# [351]	eval-mlogloss:0.07579	train-mlogloss:0.33123
# [352]	eval-mlogloss:0.07576	train-mlogloss:0.33062
# [353]	eval-mlogloss:0.07577	train-mlogloss:0.33024
# [354]	eval-mlogloss:0.07573	train-mlogloss:0.32970
# [355]	eval-mlogloss:0.07575	train-mlogloss:0.32922
# [356]	eval-mlogloss:0.07567	train-mlogloss:0.32876
# [357]	eval-mlogloss:0.07565	train-mlogloss:0.32847
# [358]	eval-mlogloss:0.07561	train-mlogloss:0.32782
# [359]	eval-mlogloss:0.07557	train-mlogloss:0.32725
# [360]	eval-mlogloss:0.07555	train-mlogloss:0.32681
# [361]	eval-mlogloss:0.07556	train-mlogloss:0.32643
# [362]	eval-mlogloss:0.07562	train-mlogloss:0.32587
# [363]	eval-mlogloss:0.07554	train-mlogloss:0.32540
# [364]	eval-mlogloss:0.07553	train-mlogloss:0.32463
# [365]	eval-mlogloss:0.07551	train-mlogloss:0.32364
# [366]	eval-mlogloss:0.07555	train-mlogloss:0.32329
# [367]	eval-mlogloss:0.07554	train-mlogloss:0.32297
# [368]	eval-mlogloss:0.07553	train-mlogloss:0.32240
# [369]	eval-mlogloss:0.07546	train-mlogloss:0.32177
# [370]	eval-mlogloss:0.07539	train-mlogloss:0.32091
# [371]	eval-mlogloss:0.07546	train-mlogloss:0.32023
# [372]	eval-mlogloss:0.07540	train-mlogloss:0.31951
# [373]	eval-mlogloss:0.07541	train-mlogloss:0.31904
# [374]	eval-mlogloss:0.07539	train-mlogloss:0.31850
# [375]	eval-mlogloss:0.07537	train-mlogloss:0.31769
# [376]	eval-mlogloss:0.07529	train-mlogloss:0.31733
# [377]	eval-mlogloss:0.07526	train-mlogloss:0.31662
# [378]	eval-mlogloss:0.07533	train-mlogloss:0.31601
# [379]	eval-mlogloss:0.07536	train-mlogloss:0.31541
# [380]	eval-mlogloss:0.07521	train-mlogloss:0.31478
# [381]	eval-mlogloss:0.07518	train-mlogloss:0.31429
# [382]	eval-mlogloss:0.07512	train-mlogloss:0.31387
# [383]	eval-mlogloss:0.07508	train-mlogloss:0.31350
# [384]	eval-mlogloss:0.07500	train-mlogloss:0.31280
# [385]	eval-mlogloss:0.07500	train-mlogloss:0.31224
# [386]	eval-mlogloss:0.07499	train-mlogloss:0.31178
# [387]	eval-mlogloss:0.07496	train-mlogloss:0.31114
# [388]	eval-mlogloss:0.07492	train-mlogloss:0.31073
# [389]	eval-mlogloss:0.07486	train-mlogloss:0.31012
# [390]	eval-mlogloss:0.07481	train-mlogloss:0.30958
# [391]	eval-mlogloss:0.07475	train-mlogloss:0.30921
# [392]	eval-mlogloss:0.07473	train-mlogloss:0.30892
# [393]	eval-mlogloss:0.07472	train-mlogloss:0.30845
# [394]	eval-mlogloss:0.07470	train-mlogloss:0.30801
# [395]	eval-mlogloss:0.07466	train-mlogloss:0.30759
# [396]	eval-mlogloss:0.07462	train-mlogloss:0.30696
# [397]	eval-mlogloss:0.07464	train-mlogloss:0.30631
# [398]	eval-mlogloss:0.07461	train-mlogloss:0.30579
# [399]	eval-mlogloss:0.07462	train-mlogloss:0.30536
# [400]	eval-mlogloss:0.07464	train-mlogloss:0.30464
# [401]	eval-mlogloss:0.07464	train-mlogloss:0.30410
# [402]	eval-mlogloss:0.07469	train-mlogloss:0.30362
# [403]	eval-mlogloss:0.07464	train-mlogloss:0.30334
# [404]	eval-mlogloss:0.07467	train-mlogloss:0.30285
# [405]	eval-mlogloss:0.07467	train-mlogloss:0.30242
# [406]	eval-mlogloss:0.07464	train-mlogloss:0.30205
# [407]	eval-mlogloss:0.07465	train-mlogloss:0.30136
# [408]	eval-mlogloss:0.07462	train-mlogloss:0.30107
# [409]	eval-mlogloss:0.07459	train-mlogloss:0.30045
# [410]	eval-mlogloss:0.07461	train-mlogloss:0.29990
# [411]	eval-mlogloss:0.07463	train-mlogloss:0.29943
# [412]	eval-mlogloss:0.07458	train-mlogloss:0.29895
# [413]	eval-mlogloss:0.07460	train-mlogloss:0.29845
# [414]	eval-mlogloss:0.07460	train-mlogloss:0.29798
# [415]	eval-mlogloss:0.07456	train-mlogloss:0.29759
# [416]	eval-mlogloss:0.07457	train-mlogloss:0.29719
# [417]	eval-mlogloss:0.07451	train-mlogloss:0.29687
# [418]	eval-mlogloss:0.07446	train-mlogloss:0.29648
# [419]	eval-mlogloss:0.07439	train-mlogloss:0.29589
# [420]	eval-mlogloss:0.07441	train-mlogloss:0.29551
# [421]	eval-mlogloss:0.07440	train-mlogloss:0.29484
# [422]	eval-mlogloss:0.07437	train-mlogloss:0.29444
# [423]	eval-mlogloss:0.07436	train-mlogloss:0.29402
# [424]	eval-mlogloss:0.07435	train-mlogloss:0.29358
# [425]	eval-mlogloss:0.07434	train-mlogloss:0.29294
# [426]	eval-mlogloss:0.07426	train-mlogloss:0.29257
# [427]	eval-mlogloss:0.07427	train-mlogloss:0.29209
# [428]	eval-mlogloss:0.07425	train-mlogloss:0.29153
# [429]	eval-mlogloss:0.07427	train-mlogloss:0.29121
# [430]	eval-mlogloss:0.07427	train-mlogloss:0.29083
# [431]	eval-mlogloss:0.07428	train-mlogloss:0.29049
# [432]	eval-mlogloss:0.07430	train-mlogloss:0.29000
# [433]	eval-mlogloss:0.07429	train-mlogloss:0.28953
# [434]	eval-mlogloss:0.07421	train-mlogloss:0.28902
# [435]	eval-mlogloss:0.07423	train-mlogloss:0.28853
# [436]	eval-mlogloss:0.07421	train-mlogloss:0.28813
# [437]	eval-mlogloss:0.07420	train-mlogloss:0.28784
# [438]	eval-mlogloss:0.07419	train-mlogloss:0.28724
# [439]	eval-mlogloss:0.07418	train-mlogloss:0.28686
# [440]	eval-mlogloss:0.07408	train-mlogloss:0.28628
# [441]	eval-mlogloss:0.07408	train-mlogloss:0.28601
# [442]	eval-mlogloss:0.07407	train-mlogloss:0.28561
# [443]	eval-mlogloss:0.07408	train-mlogloss:0.28529
# [444]	eval-mlogloss:0.07408	train-mlogloss:0.28506
# [445]	eval-mlogloss:0.07404	train-mlogloss:0.28463
# [446]	eval-mlogloss:0.07403	train-mlogloss:0.28427
# [447]	eval-mlogloss:0.07396	train-mlogloss:0.28386
# [448]	eval-mlogloss:0.07391	train-mlogloss:0.28345
# [449]	eval-mlogloss:0.07390	train-mlogloss:0.28313
# [450]	eval-mlogloss:0.07386	train-mlogloss:0.28285
# [451]	eval-mlogloss:0.07387	train-mlogloss:0.28235
# [452]	eval-mlogloss:0.07382	train-mlogloss:0.28181
# [453]	eval-mlogloss:0.07382	train-mlogloss:0.28140
# [454]	eval-mlogloss:0.07383	train-mlogloss:0.28092
# [455]	eval-mlogloss:0.07386	train-mlogloss:0.28043
# [456]	eval-mlogloss:0.07385	train-mlogloss:0.28001
# [457]	eval-mlogloss:0.07385	train-mlogloss:0.27958
# [458]	eval-mlogloss:0.07387	train-mlogloss:0.27932
# [459]	eval-mlogloss:0.07389	train-mlogloss:0.27900
# [460]	eval-mlogloss:0.07390	train-mlogloss:0.27850
# [461]	eval-mlogloss:0.07393	train-mlogloss:0.27817
# [462]	eval-mlogloss:0.07392	train-mlogloss:0.27773
# [463]	eval-mlogloss:0.07394	train-mlogloss:0.27742
# [464]	eval-mlogloss:0.07393	train-mlogloss:0.27691
# [465]	eval-mlogloss:0.07389	train-mlogloss:0.27675
# [466]	eval-mlogloss:0.07391	train-mlogloss:0.27647
# [467]	eval-mlogloss:0.07394	train-mlogloss:0.27619
# [468]	eval-mlogloss:0.07394	train-mlogloss:0.27572
# [469]	eval-mlogloss:0.07391	train-mlogloss:0.27523
# [470]	eval-mlogloss:0.07390	train-mlogloss:0.27478
# [471]	eval-mlogloss:0.07390	train-mlogloss:0.27443
# [472]	eval-mlogloss:0.07392	train-mlogloss:0.27401
# [473]	eval-mlogloss:0.07385	train-mlogloss:0.27363
# [474]	eval-mlogloss:0.07390	train-mlogloss:0.27322
# [475]	eval-mlogloss:0.07392	train-mlogloss:0.27276
# [476]	eval-mlogloss:0.07393	train-mlogloss:0.27221
# [477]	eval-mlogloss:0.07392	train-mlogloss:0.27172
# [478]	eval-mlogloss:0.07389	train-mlogloss:0.27133
# [479]	eval-mlogloss:0.07384	train-mlogloss:0.27077
# [480]	eval-mlogloss:0.07380	train-mlogloss:0.27036
# [481]	eval-mlogloss:0.07376	train-mlogloss:0.27000
# [482]	eval-mlogloss:0.07377	train-mlogloss:0.26963
# [483]	eval-mlogloss:0.07377	train-mlogloss:0.26923
# [484]	eval-mlogloss:0.07378	train-mlogloss:0.26885
# [485]	eval-mlogloss:0.07380	train-mlogloss:0.26838
# [486]	eval-mlogloss:0.07376	train-mlogloss:0.26805
# [487]	eval-mlogloss:0.07378	train-mlogloss:0.26769
# [488]	eval-mlogloss:0.07379	train-mlogloss:0.26735
# [489]	eval-mlogloss:0.07379	train-mlogloss:0.26706
# [490]	eval-mlogloss:0.07378	train-mlogloss:0.26663
# [491]	eval-mlogloss:0.07380	train-mlogloss:0.26637
# [492]	eval-mlogloss:0.07380	train-mlogloss:0.26597
# [493]	eval-mlogloss:0.07383	train-mlogloss:0.26560
# [494]	eval-mlogloss:0.07382	train-mlogloss:0.26519
# [495]	eval-mlogloss:0.07383	train-mlogloss:0.26491
# [496]	eval-mlogloss:0.07382	train-mlogloss:0.26459
# [497]	eval-mlogloss:0.07384	train-mlogloss:0.26431
# [498]	eval-mlogloss:0.07379	train-mlogloss:0.26406
# [499]	eval-mlogloss:0.07380	train-mlogloss:0.26382
# [500]	eval-mlogloss:0.07380	train-mlogloss:0.26352
# [501]	eval-mlogloss:0.07379	train-mlogloss:0.26302
# [502]	eval-mlogloss:0.07378	train-mlogloss:0.26246
# [503]	eval-mlogloss:0.07375	train-mlogloss:0.26208
# [504]	eval-mlogloss:0.07374	train-mlogloss:0.26168
# [505]	eval-mlogloss:0.07376	train-mlogloss:0.26121
# [506]	eval-mlogloss:0.07375	train-mlogloss:0.26085
# [507]	eval-mlogloss:0.07375	train-mlogloss:0.26038
# [508]	eval-mlogloss:0.07372	train-mlogloss:0.25992
# [509]	eval-mlogloss:0.07372	train-mlogloss:0.25959
# [510]	eval-mlogloss:0.07373	train-mlogloss:0.25923
# [511]	eval-mlogloss:0.07380	train-mlogloss:0.25883
# [512]	eval-mlogloss:0.07380	train-mlogloss:0.25840
# [513]	eval-mlogloss:0.07378	train-mlogloss:0.25801
# [514]	eval-mlogloss:0.07377	train-mlogloss:0.25772
# [515]	eval-mlogloss:0.07378	train-mlogloss:0.25749
# [516]	eval-mlogloss:0.07376	train-mlogloss:0.25708
# [517]	eval-mlogloss:0.07372	train-mlogloss:0.25675
# [518]	eval-mlogloss:0.07371	train-mlogloss:0.25662
# [519]	eval-mlogloss:0.07369	train-mlogloss:0.25630
# [520]	eval-mlogloss:0.07370	train-mlogloss:0.25582
# [521]	eval-mlogloss:0.07371	train-mlogloss:0.25542
# [522]	eval-mlogloss:0.07372	train-mlogloss:0.25493
# [523]	eval-mlogloss:0.07375	train-mlogloss:0.25470
# [524]	eval-mlogloss:0.07369	train-mlogloss:0.25437
# [525]	eval-mlogloss:0.07363	train-mlogloss:0.25360
# [526]	eval-mlogloss:0.07364	train-mlogloss:0.25315
# [527]	eval-mlogloss:0.07359	train-mlogloss:0.25289
# [528]	eval-mlogloss:0.07359	train-mlogloss:0.25241
# [529]	eval-mlogloss:0.07358	train-mlogloss:0.25202
# [530]	eval-mlogloss:0.07360	train-mlogloss:0.25145
# [531]	eval-mlogloss:0.07360	train-mlogloss:0.25109
# [532]	eval-mlogloss:0.07360	train-mlogloss:0.25056
# [533]	eval-mlogloss:0.07359	train-mlogloss:0.25022
# [534]	eval-mlogloss:0.07358	train-mlogloss:0.24995
# [535]	eval-mlogloss:0.07359	train-mlogloss:0.24966
# [536]	eval-mlogloss:0.07353	train-mlogloss:0.24923
# [537]	eval-mlogloss:0.07353	train-mlogloss:0.24895
# [538]	eval-mlogloss:0.07350	train-mlogloss:0.24854
# [539]	eval-mlogloss:0.07351	train-mlogloss:0.24805
# [540]	eval-mlogloss:0.07349	train-mlogloss:0.24776
# [541]	eval-mlogloss:0.07350	train-mlogloss:0.24748
# [542]	eval-mlogloss:0.07352	train-mlogloss:0.24725
# [543]	eval-mlogloss:0.07357	train-mlogloss:0.24699
# [544]	eval-mlogloss:0.07355	train-mlogloss:0.24667
# [545]	eval-mlogloss:0.07353	train-mlogloss:0.24640
# [546]	eval-mlogloss:0.07355	train-mlogloss:0.24619
# [547]	eval-mlogloss:0.07354	train-mlogloss:0.24577
# [548]	eval-mlogloss:0.07355	train-mlogloss:0.24548
# [549]	eval-mlogloss:0.07356	train-mlogloss:0.24516
# [550]	eval-mlogloss:0.07356	train-mlogloss:0.24487
# [551]	eval-mlogloss:0.07357	train-mlogloss:0.24456
# [552]	eval-mlogloss:0.07355	train-mlogloss:0.24407
# [553]	eval-mlogloss:0.07353	train-mlogloss:0.24373
# [554]	eval-mlogloss:0.07351	train-mlogloss:0.24348
# [555]	eval-mlogloss:0.07351	train-mlogloss:0.24301
# [556]	eval-mlogloss:0.07351	train-mlogloss:0.24263
# [557]	eval-mlogloss:0.07353	train-mlogloss:0.24231
# [558]	eval-mlogloss:0.07348	train-mlogloss:0.24198
# [559]	eval-mlogloss:0.07348	train-mlogloss:0.24182
# [560]	eval-mlogloss:0.07348	train-mlogloss:0.24149
# [561]	eval-mlogloss:0.07346	train-mlogloss:0.24105
# [562]	eval-mlogloss:0.07347	train-mlogloss:0.24063
# [563]	eval-mlogloss:0.07344	train-mlogloss:0.24017
# [564]	eval-mlogloss:0.07347	train-mlogloss:0.23980
# [565]	eval-mlogloss:0.07347	train-mlogloss:0.23935
# [566]	eval-mlogloss:0.07348	train-mlogloss:0.23891
# [567]	eval-mlogloss:0.07348	train-mlogloss:0.23862
# [568]	eval-mlogloss:0.07350	train-mlogloss:0.23835
# [569]	eval-mlogloss:0.07351	train-mlogloss:0.23812
# [570]	eval-mlogloss:0.07349	train-mlogloss:0.23778
# [571]	eval-mlogloss:0.07353	train-mlogloss:0.23755
# [572]	eval-mlogloss:0.07353	train-mlogloss:0.23729
# [573]	eval-mlogloss:0.07353	train-mlogloss:0.23692
# [574]	eval-mlogloss:0.07356	train-mlogloss:0.23672
# [575]	eval-mlogloss:0.07357	train-mlogloss:0.23644
# [576]	eval-mlogloss:0.07359	train-mlogloss:0.23605
# [577]	eval-mlogloss:0.07361	train-mlogloss:0.23574
# [578]	eval-mlogloss:0.07361	train-mlogloss:0.23537
# [579]	eval-mlogloss:0.07360	train-mlogloss:0.23500
# [580]	eval-mlogloss:0.07361	train-mlogloss:0.23467
# [581]	eval-mlogloss:0.07361	train-mlogloss:0.23430
# [582]	eval-mlogloss:0.07360	train-mlogloss:0.23391
# [583]	eval-mlogloss:0.07362	train-mlogloss:0.23357
# [584]	eval-mlogloss:0.07361	train-mlogloss:0.23337
# [585]	eval-mlogloss:0.07365	train-mlogloss:0.23312
# [586]	eval-mlogloss:0.07363	train-mlogloss:0.23281
# [587]	eval-mlogloss:0.07364	train-mlogloss:0.23238
# [588]	eval-mlogloss:0.07366	train-mlogloss:0.23201
# [589]	eval-mlogloss:0.07368	train-mlogloss:0.23165
# [590]	eval-mlogloss:0.07366	train-mlogloss:0.23118
# [591]	eval-mlogloss:0.07369	train-mlogloss:0.23095
# [592]	eval-mlogloss:0.07371	train-mlogloss:0.23070
# [593]	eval-mlogloss:0.07370	train-mlogloss:0.23047
# [594]	eval-mlogloss:0.07369	train-mlogloss:0.23007
# [595]	eval-mlogloss:0.07370	train-mlogloss:0.22968
# [596]	eval-mlogloss:0.07371	train-mlogloss:0.22923
# [597]	eval-mlogloss:0.07373	train-mlogloss:0.22883
# [598]	eval-mlogloss:0.07375	train-mlogloss:0.22851
# [599]	eval-mlogloss:0.07376	train-mlogloss:0.22825
# [600]	eval-mlogloss:0.07376	train-mlogloss:0.22793
# [601]	eval-mlogloss:0.07376	train-mlogloss:0.22767
# [602]	eval-mlogloss:0.07377	train-mlogloss:0.22728
# [603]	eval-mlogloss:0.07381	train-mlogloss:0.22708
# [604]	eval-mlogloss:0.07381	train-mlogloss:0.22682
# [605]	eval-mlogloss:0.07382	train-mlogloss:0.22648
# [606]	eval-mlogloss:0.07383	train-mlogloss:0.22624
# [607]	eval-mlogloss:0.07384	train-mlogloss:0.22599
# [608]	eval-mlogloss:0.07384	train-mlogloss:0.22568
# [609]	eval-mlogloss:0.07385	train-mlogloss:0.22546
# [610]	eval-mlogloss:0.07387	train-mlogloss:0.22522
# [611]	eval-mlogloss:0.07387	train-mlogloss:0.22507
# [612]	eval-mlogloss:0.07388	train-mlogloss:0.22477
# [613]	eval-mlogloss:0.07387	train-mlogloss:0.22452
# [614]	eval-mlogloss:0.07388	train-mlogloss:0.22420
# [615]	eval-mlogloss:0.07388	train-mlogloss:0.22401
# [616]	eval-mlogloss:0.07391	train-mlogloss:0.22365
# [617]	eval-mlogloss:0.07391	train-mlogloss:0.22340
# [618]	eval-mlogloss:0.07389	train-mlogloss:0.22307
# [619]	eval-mlogloss:0.07392	train-mlogloss:0.22274
# [620]	eval-mlogloss:0.07396	train-mlogloss:0.22237
# [621]	eval-mlogloss:0.07399	train-mlogloss:0.22209
# [622]	eval-mlogloss:0.07400	train-mlogloss:0.22170
# [623]	eval-mlogloss:0.07402	train-mlogloss:0.22148
# [624]	eval-mlogloss:0.07405	train-mlogloss:0.22119
# [625]	eval-mlogloss:0.07404	train-mlogloss:0.22086
# [626]	eval-mlogloss:0.07403	train-mlogloss:0.22049
# [627]	eval-mlogloss:0.07403	train-mlogloss:0.22026
# [628]	eval-mlogloss:0.07407	train-mlogloss:0.22005
# [629]	eval-mlogloss:0.07408	train-mlogloss:0.21972
# [630]	eval-mlogloss:0.07410	train-mlogloss:0.21947
# [631]	eval-mlogloss:0.07411	train-mlogloss:0.21920
# [632]	eval-mlogloss:0.07414	train-mlogloss:0.21899
# [633]	eval-mlogloss:0.07417	train-mlogloss:0.21880
# [634]	eval-mlogloss:0.07415	train-mlogloss:0.21846
# [635]	eval-mlogloss:0.07413	train-mlogloss:0.21805
# [636]	eval-mlogloss:0.07415	train-mlogloss:0.21762
# [637]	eval-mlogloss:0.07412	train-mlogloss:0.21738
# [638]	eval-mlogloss:0.07411	train-mlogloss:0.21713
# [639]	eval-mlogloss:0.07413	train-mlogloss:0.21694
# [640]	eval-mlogloss:0.07416	train-mlogloss:0.21662
# [641]	eval-mlogloss:0.07418	train-mlogloss:0.21640
# [642]	eval-mlogloss:0.07421	train-mlogloss:0.21607
# [643]	eval-mlogloss:0.07423	train-mlogloss:0.21572
# [644]	eval-mlogloss:0.07423	train-mlogloss:0.21546
# [645]	eval-mlogloss:0.07425	train-mlogloss:0.21518
# [646]	eval-mlogloss:0.07423	train-mlogloss:0.21497
# [647]	eval-mlogloss:0.07425	train-mlogloss:0.21472
# [648]	eval-mlogloss:0.07427	train-mlogloss:0.21449
# [649]	eval-mlogloss:0.07427	train-mlogloss:0.21432
# [650]	eval-mlogloss:0.07427	train-mlogloss:0.21396
# [651]	eval-mlogloss:0.07427	train-mlogloss:0.21370
# [652]	eval-mlogloss:0.07424	train-mlogloss:0.21342
# [653]	eval-mlogloss:0.07423	train-mlogloss:0.21319
# [654]	eval-mlogloss:0.07424	train-mlogloss:0.21289
# [655]	eval-mlogloss:0.07427	train-mlogloss:0.21255
# [656]	eval-mlogloss:0.07427	train-mlogloss:0.21227
# [657]	eval-mlogloss:0.07430	train-mlogloss:0.21199
# [658]	eval-mlogloss:0.07430	train-mlogloss:0.21181
# [659]	eval-mlogloss:0.07434	train-mlogloss:0.21157
# [660]	eval-mlogloss:0.07435	train-mlogloss:0.21130
# [661]	eval-mlogloss:0.07434	train-mlogloss:0.21105
# [662]	eval-mlogloss:0.07435	train-mlogloss:0.21077
# [663]	eval-mlogloss:0.07435	train-mlogloss:0.21058
# [664]	eval-mlogloss:0.07433	train-mlogloss:0.21040
# [665]	eval-mlogloss:0.07438	train-mlogloss:0.21006
# [666]	eval-mlogloss:0.07440	train-mlogloss:0.20981
# [667]	eval-mlogloss:0.07441	train-mlogloss:0.20957
# [668]	eval-mlogloss:0.07446	train-mlogloss:0.20924
# [669]	eval-mlogloss:0.07447	train-mlogloss:0.20891
# [670]	eval-mlogloss:0.07448	train-mlogloss:0.20866
# [671]	eval-mlogloss:0.07446	train-mlogloss:0.20839
# [672]	eval-mlogloss:0.07448	train-mlogloss:0.20815
# [673]	eval-mlogloss:0.07449	train-mlogloss:0.20788
# [674]	eval-mlogloss:0.07452	train-mlogloss:0.20766
# [675]	eval-mlogloss:0.07452	train-mlogloss:0.20744
# [676]	eval-mlogloss:0.07452	train-mlogloss:0.20718
# [677]	eval-mlogloss:0.07454	train-mlogloss:0.20699
# [678]	eval-mlogloss:0.07451	train-mlogloss:0.20662
# [679]	eval-mlogloss:0.07451	train-mlogloss:0.20636
# [680]	eval-mlogloss:0.07450	train-mlogloss:0.20624
# [681]	eval-mlogloss:0.07450	train-mlogloss:0.20587
# [682]	eval-mlogloss:0.07452	train-mlogloss:0.20563
# [683]	eval-mlogloss:0.07452	train-mlogloss:0.20545
# [684]	eval-mlogloss:0.07458	train-mlogloss:0.20506
# [685]	eval-mlogloss:0.07460	train-mlogloss:0.20480
# [686]	eval-mlogloss:0.07458	train-mlogloss:0.20458
# [687]	eval-mlogloss:0.07462	train-mlogloss:0.20428
# [688]	eval-mlogloss:0.07464	train-mlogloss:0.20392
# [689]	eval-mlogloss:0.07467	train-mlogloss:0.20363
# [690]	eval-mlogloss:0.07466	train-mlogloss:0.20326
# [691]	eval-mlogloss:0.07469	train-mlogloss:0.20297
# [692]	eval-mlogloss:0.07470	train-mlogloss:0.20275
# [693]	eval-mlogloss:0.07469	train-mlogloss:0.20253
# [694]	eval-mlogloss:0.07470	train-mlogloss:0.20223
# [695]	eval-mlogloss:0.07469	train-mlogloss:0.20206
# [696]	eval-mlogloss:0.07471	train-mlogloss:0.20169
# [697]	eval-mlogloss:0.07473	train-mlogloss:0.20136
# [698]	eval-mlogloss:0.07474	train-mlogloss:0.20101
# [699]	eval-mlogloss:0.07477	train-mlogloss:0.20083
# [700]	eval-mlogloss:0.07477	train-mlogloss:0.20061
# [701]	eval-mlogloss:0.07474	train-mlogloss:0.20033
# [702]	eval-mlogloss:0.07472	train-mlogloss:0.20006
# [703]	eval-mlogloss:0.07475	train-mlogloss:0.19979
# [704]	eval-mlogloss:0.07475	train-mlogloss:0.19961
# [705]	eval-mlogloss:0.07472	train-mlogloss:0.19941
# [706]	eval-mlogloss:0.07472	train-mlogloss:0.19923
# [707]	eval-mlogloss:0.07472	train-mlogloss:0.19909
# [708]	eval-mlogloss:0.07474	train-mlogloss:0.19894
# [709]	eval-mlogloss:0.07478	train-mlogloss:0.19873
# [710]	eval-mlogloss:0.07479	train-mlogloss:0.19848
# [711]	eval-mlogloss:0.07484	train-mlogloss:0.19826
# [712]	eval-mlogloss:0.07482	train-mlogloss:0.19812
# [713]	eval-mlogloss:0.07482	train-mlogloss:0.19784
# [714]	eval-mlogloss:0.07483	train-mlogloss:0.19766
# [715]	eval-mlogloss:0.07485	train-mlogloss:0.19734
# [716]	eval-mlogloss:0.07485	train-mlogloss:0.19715
# [717]	eval-mlogloss:0.07485	train-mlogloss:0.19677
# [718]	eval-mlogloss:0.07488	train-mlogloss:0.19655
# [719]	eval-mlogloss:0.07489	train-mlogloss:0.19629
# [720]	eval-mlogloss:0.07490	train-mlogloss:0.19611
# [721]	eval-mlogloss:0.07490	train-mlogloss:0.19581
# [722]	eval-mlogloss:0.07488	train-mlogloss:0.19557
# [723]	eval-mlogloss:0.07488	train-mlogloss:0.19538
# [724]	eval-mlogloss:0.07487	train-mlogloss:0.19521
# [725]	eval-mlogloss:0.07486	train-mlogloss:0.19495
# [726]	eval-mlogloss:0.07487	train-mlogloss:0.19476
# [727]	eval-mlogloss:0.07488	train-mlogloss:0.19441
# [728]	eval-mlogloss:0.07489	train-mlogloss:0.19413
# [729]	eval-mlogloss:0.07486	train-mlogloss:0.19390
# [730]	eval-mlogloss:0.07486	train-mlogloss:0.19356
# [731]	eval-mlogloss:0.07485	train-mlogloss:0.19339
# [732]	eval-mlogloss:0.07486	train-mlogloss:0.19317
# [733]	eval-mlogloss:0.07486	train-mlogloss:0.19292
# [734]	eval-mlogloss:0.07486	train-mlogloss:0.19266
# [735]	eval-mlogloss:0.07487	train-mlogloss:0.19243
# [736]	eval-mlogloss:0.07490	train-mlogloss:0.19217
# [737]	eval-mlogloss:0.07490	train-mlogloss:0.19183
# [738]	eval-mlogloss:0.07491	train-mlogloss:0.19153
# [739]	eval-mlogloss:0.07488	train-mlogloss:0.19129
# [740]	eval-mlogloss:0.07487	train-mlogloss:0.19107
# [741]	eval-mlogloss:0.07489	train-mlogloss:0.19082
# [742]	eval-mlogloss:0.07486	train-mlogloss:0.19058
# [743]	eval-mlogloss:0.07487	train-mlogloss:0.19029
# [744]	eval-mlogloss:0.07486	train-mlogloss:0.19010
# [745]	eval-mlogloss:0.07487	train-mlogloss:0.18988
# [746]	eval-mlogloss:0.07488	train-mlogloss:0.18965
# [747]	eval-mlogloss:0.07488	train-mlogloss:0.18939
# [748]	eval-mlogloss:0.07489	train-mlogloss:0.18900
# [749]	eval-mlogloss:0.07490	train-mlogloss:0.18881
# [750]	eval-mlogloss:0.07492	train-mlogloss:0.18856
# [751]	eval-mlogloss:0.07492	train-mlogloss:0.18826
# [752]	eval-mlogloss:0.07493	train-mlogloss:0.18801
# [753]	eval-mlogloss:0.07494	train-mlogloss:0.18774
# [754]	eval-mlogloss:0.07492	train-mlogloss:0.18733
# [755]	eval-mlogloss:0.07494	train-mlogloss:0.18709
# [756]	eval-mlogloss:0.07493	train-mlogloss:0.18692
# [757]	eval-mlogloss:0.07493	train-mlogloss:0.18663
# [758]	eval-mlogloss:0.07492	train-mlogloss:0.18642
# [759]	eval-mlogloss:0.07489	train-mlogloss:0.18622
# [760]	eval-mlogloss:0.07491	train-mlogloss:0.18599
# [761]	eval-mlogloss:0.07493	train-mlogloss:0.18573
# [762]	eval-mlogloss:0.07490	train-mlogloss:0.18554
# [763]	eval-mlogloss:0.07493	train-mlogloss:0.18542
# [764]	eval-mlogloss:0.07495	train-mlogloss:0.18517
# [765]	eval-mlogloss:0.07494	train-mlogloss:0.18503
# [766]	eval-mlogloss:0.07496	train-mlogloss:0.18477
# [767]	eval-mlogloss:0.07495	train-mlogloss:0.18450
# [768]	eval-mlogloss:0.07498	train-mlogloss:0.18430
# [769]	eval-mlogloss:0.07499	train-mlogloss:0.18411
# [770]	eval-mlogloss:0.07496	train-mlogloss:0.18400
# [771]	eval-mlogloss:0.07496	train-mlogloss:0.18389
# [772]	eval-mlogloss:0.07497	train-mlogloss:0.18372
# [773]	eval-mlogloss:0.07500	train-mlogloss:0.18347
# [774]	eval-mlogloss:0.07502	train-mlogloss:0.18323
# [775]	eval-mlogloss:0.07500	train-mlogloss:0.18294
# [776]	eval-mlogloss:0.07502	train-mlogloss:0.18267
# [777]	eval-mlogloss:0.07503	train-mlogloss:0.18239
# [778]	eval-mlogloss:0.07505	train-mlogloss:0.18214
# [779]	eval-mlogloss:0.07507	train-mlogloss:0.18192
# [780]	eval-mlogloss:0.07509	train-mlogloss:0.18158
# [781]	eval-mlogloss:0.07512	train-mlogloss:0.18132
# [782]	eval-mlogloss:0.07512	train-mlogloss:0.18097
# [783]	eval-mlogloss:0.07512	train-mlogloss:0.18078
# [784]	eval-mlogloss:0.07512	train-mlogloss:0.18063
# [785]	eval-mlogloss:0.07512	train-mlogloss:0.18049
# [786]	eval-mlogloss:0.07513	train-mlogloss:0.18032
# [787]	eval-mlogloss:0.07512	train-mlogloss:0.18009
# [788]	eval-mlogloss:0.07515	train-mlogloss:0.17981
# [789]	eval-mlogloss:0.07517	train-mlogloss:0.17959
# [790]	eval-mlogloss:0.07518	train-mlogloss:0.17942
# [791]	eval-mlogloss:0.07522	train-mlogloss:0.17924
# [792]	eval-mlogloss:0.07525	train-mlogloss:0.17894
# [793]	eval-mlogloss:0.07525	train-mlogloss:0.17865
# [794]	eval-mlogloss:0.07526	train-mlogloss:0.17836
# [795]	eval-mlogloss:0.07527	train-mlogloss:0.17819
# [796]	eval-mlogloss:0.07529	train-mlogloss:0.17808
# [797]	eval-mlogloss:0.07536	train-mlogloss:0.17782
# [798]	eval-mlogloss:0.07536	train-mlogloss:0.17766
# [799]	eval-mlogloss:0.07538	train-mlogloss:0.17745
# [800]	eval-mlogloss:0.07540	train-mlogloss:0.17718
# [801]	eval-mlogloss:0.07541	train-mlogloss:0.17706
# [802]	eval-mlogloss:0.07541	train-mlogloss:0.17688
# [803]	eval-mlogloss:0.07541	train-mlogloss:0.17675
# [804]	eval-mlogloss:0.07544	train-mlogloss:0.17651
# [805]	eval-mlogloss:0.07543	train-mlogloss:0.17624
# [806]	eval-mlogloss:0.07545	train-mlogloss:0.17606
# [807]	eval-mlogloss:0.07548	train-mlogloss:0.17584
# [808]	eval-mlogloss:0.07550	train-mlogloss:0.17565
# [809]	eval-mlogloss:0.07551	train-mlogloss:0.17549
# [810]	eval-mlogloss:0.07551	train-mlogloss:0.17534
# [811]	eval-mlogloss:0.07549	train-mlogloss:0.17510
# [812]	eval-mlogloss:0.07548	train-mlogloss:0.17496
# [813]	eval-mlogloss:0.07550	train-mlogloss:0.17482
# [814]	eval-mlogloss:0.07552	train-mlogloss:0.17462
# [815]	eval-mlogloss:0.07554	train-mlogloss:0.17448
# [816]	eval-mlogloss:0.07554	train-mlogloss:0.17427
# [817]	eval-mlogloss:0.07556	train-mlogloss:0.17406
# [818]	eval-mlogloss:0.07557	train-mlogloss:0.17389
# [819]	eval-mlogloss:0.07557	train-mlogloss:0.17374
# [820]	eval-mlogloss:0.07558	train-mlogloss:0.17354
# [821]	eval-mlogloss:0.07561	train-mlogloss:0.17339
# [822]	eval-mlogloss:0.07562	train-mlogloss:0.17319
# [823]	eval-mlogloss:0.07563	train-mlogloss:0.17303
# [824]	eval-mlogloss:0.07562	train-mlogloss:0.17289
# [825]	eval-mlogloss:0.07563	train-mlogloss:0.17269
# [826]	eval-mlogloss:0.07563	train-mlogloss:0.17256
# [827]	eval-mlogloss:0.07563	train-mlogloss:0.17240
# [828]	eval-mlogloss:0.07562	train-mlogloss:0.17223
# [829]	eval-mlogloss:0.07563	train-mlogloss:0.17210
# [830]	eval-mlogloss:0.07564	train-mlogloss:0.17181
# [831]	eval-mlogloss:0.07567	train-mlogloss:0.17166
# [832]	eval-mlogloss:0.07570	train-mlogloss:0.17147
# [833]	eval-mlogloss:0.07571	train-mlogloss:0.17125
# [834]	eval-mlogloss:0.07570	train-mlogloss:0.17102
# [835]	eval-mlogloss:0.07572	train-mlogloss:0.17079
# [836]	eval-mlogloss:0.07570	train-mlogloss:0.17063
# [837]	eval-mlogloss:0.07571	train-mlogloss:0.17050
# [838]	eval-mlogloss:0.07575	train-mlogloss:0.17035
# [839]	eval-mlogloss:0.07574	train-mlogloss:0.17011
# [840]	eval-mlogloss:0.07577	train-mlogloss:0.16988
# [841]	eval-mlogloss:0.07580	train-mlogloss:0.16964
# [842]	eval-mlogloss:0.07582	train-mlogloss:0.16935
# [843]	eval-mlogloss:0.07583	train-mlogloss:0.16909
# [844]	eval-mlogloss:0.07585	train-mlogloss:0.16886
# [845]	eval-mlogloss:0.07586	train-mlogloss:0.16866
# [846]	eval-mlogloss:0.07587	train-mlogloss:0.16849
# [847]	eval-mlogloss:0.07590	train-mlogloss:0.16838
# [848]	eval-mlogloss:0.07589	train-mlogloss:0.16822
# [849]	eval-mlogloss:0.07593	train-mlogloss:0.16809
# [850]	eval-mlogloss:0.07597	train-mlogloss:0.16796
# [851]	eval-mlogloss:0.07598	train-mlogloss:0.16781
# [852]	eval-mlogloss:0.07600	train-mlogloss:0.16758
# [853]	eval-mlogloss:0.07601	train-mlogloss:0.16739
# [854]	eval-mlogloss:0.07602	train-mlogloss:0.16722
# [855]	eval-mlogloss:0.07602	train-mlogloss:0.16701
# [856]	eval-mlogloss:0.07603	train-mlogloss:0.16686
# [857]	eval-mlogloss:0.07604	train-mlogloss:0.16667
# [858]	eval-mlogloss:0.07605	train-mlogloss:0.16643
# [859]	eval-mlogloss:0.07605	train-mlogloss:0.16628
# [860]	eval-mlogloss:0.07608	train-mlogloss:0.16617
# [861]	eval-mlogloss:0.07611	train-mlogloss:0.16597
# [862]	eval-mlogloss:0.07610	train-mlogloss:0.16571
# [863]	eval-mlogloss:0.07612	train-mlogloss:0.16549
# [864]	eval-mlogloss:0.07613	train-mlogloss:0.16533
# [865]	eval-mlogloss:0.07616	train-mlogloss:0.16508
# [866]	eval-mlogloss:0.07616	train-mlogloss:0.16489
# [867]	eval-mlogloss:0.07618	train-mlogloss:0.16464
# [868]	eval-mlogloss:0.07622	train-mlogloss:0.16445
# [869]	eval-mlogloss:0.07625	train-mlogloss:0.16423
# [870]	eval-mlogloss:0.07625	train-mlogloss:0.16405
# [871]	eval-mlogloss:0.07623	train-mlogloss:0.16375
# [872]	eval-mlogloss:0.07622	train-mlogloss:0.16352
# [873]	eval-mlogloss:0.07623	train-mlogloss:0.16323
# [874]	eval-mlogloss:0.07623	train-mlogloss:0.16306
# [875]	eval-mlogloss:0.07623	train-mlogloss:0.16289
# [876]	eval-mlogloss:0.07625	train-mlogloss:0.16256
# [877]	eval-mlogloss:0.07628	train-mlogloss:0.16239
# [878]	eval-mlogloss:0.07628	train-mlogloss:0.16217
# [879]	eval-mlogloss:0.07633	train-mlogloss:0.16201
# [880]	eval-mlogloss:0.07635	train-mlogloss:0.16188
# [881]	eval-mlogloss:0.07634	train-mlogloss:0.16170
# [882]	eval-mlogloss:0.07638	train-mlogloss:0.16154
# [883]	eval-mlogloss:0.07638	train-mlogloss:0.16135
# [884]	eval-mlogloss:0.07638	train-mlogloss:0.16112
# [885]	eval-mlogloss:0.07639	train-mlogloss:0.16098
# [886]	eval-mlogloss:0.07638	train-mlogloss:0.16068
# [887]	eval-mlogloss:0.07638	train-mlogloss:0.16052
# [888]	eval-mlogloss:0.07641	train-mlogloss:0.16026
# [889]	eval-mlogloss:0.07644	train-mlogloss:0.16009
# [890]	eval-mlogloss:0.07646	train-mlogloss:0.15991
# [891]	eval-mlogloss:0.07647	train-mlogloss:0.15970
# [892]	eval-mlogloss:0.07644	train-mlogloss:0.15957
# [893]	eval-mlogloss:0.07645	train-mlogloss:0.15943
# [894]	eval-mlogloss:0.07647	train-mlogloss:0.15928
# [895]	eval-mlogloss:0.07647	train-mlogloss:0.15911
# [896]	eval-mlogloss:0.07647	train-mlogloss:0.15887
# [897]	eval-mlogloss:0.07647	train-mlogloss:0.15872
# [898]	eval-mlogloss:0.07650	train-mlogloss:0.15857
# [899]	eval-mlogloss:0.07650	train-mlogloss:0.15848
# [900]	eval-mlogloss:0.07648	train-mlogloss:0.15825
# [901]	eval-mlogloss:0.07650	train-mlogloss:0.15809
# [902]	eval-mlogloss:0.07652	train-mlogloss:0.15795
# [903]	eval-mlogloss:0.07654	train-mlogloss:0.15775
# [904]	eval-mlogloss:0.07655	train-mlogloss:0.15750
# [905]	eval-mlogloss:0.07653	train-mlogloss:0.15733
# [906]	eval-mlogloss:0.07655	train-mlogloss:0.15717
# [907]	eval-mlogloss:0.07657	train-mlogloss:0.15703
# [908]	eval-mlogloss:0.07660	train-mlogloss:0.15690
# [909]	eval-mlogloss:0.07660	train-mlogloss:0.15673
# [910]	eval-mlogloss:0.07662	train-mlogloss:0.15655
# [911]	eval-mlogloss:0.07662	train-mlogloss:0.15639
# [912]	eval-mlogloss:0.07662	train-mlogloss:0.15612
# [913]	eval-mlogloss:0.07664	train-mlogloss:0.15596
# [914]	eval-mlogloss:0.07666	train-mlogloss:0.15571
# [915]	eval-mlogloss:0.07668	train-mlogloss:0.15557
# [916]	eval-mlogloss:0.07669	train-mlogloss:0.15538
# [917]	eval-mlogloss:0.07671	train-mlogloss:0.15521
# [918]	eval-mlogloss:0.07671	train-mlogloss:0.15497
# [919]	eval-mlogloss:0.07671	train-mlogloss:0.15475
# [920]	eval-mlogloss:0.07673	train-mlogloss:0.15457
# [921]	eval-mlogloss:0.07672	train-mlogloss:0.15436
# [922]	eval-mlogloss:0.07673	train-mlogloss:0.15417
# [923]	eval-mlogloss:0.07674	train-mlogloss:0.15396
# [924]	eval-mlogloss:0.07674	train-mlogloss:0.15382
# [925]	eval-mlogloss:0.07676	train-mlogloss:0.15373
# [926]	eval-mlogloss:0.07676	train-mlogloss:0.15360
# [927]	eval-mlogloss:0.07678	train-mlogloss:0.15343
# [928]	eval-mlogloss:0.07678	train-mlogloss:0.15332
# [929]	eval-mlogloss:0.07677	train-mlogloss:0.15314
# [930]	eval-mlogloss:0.07678	train-mlogloss:0.15295
# [931]	eval-mlogloss:0.07678	train-mlogloss:0.15268
# [932]	eval-mlogloss:0.07681	train-mlogloss:0.15251
# [933]	eval-mlogloss:0.07684	train-mlogloss:0.15232
# [934]	eval-mlogloss:0.07686	train-mlogloss:0.15214
# [935]	eval-mlogloss:0.07688	train-mlogloss:0.15197
# [936]	eval-mlogloss:0.07688	train-mlogloss:0.15180
# [937]	eval-mlogloss:0.07690	train-mlogloss:0.15169
# [938]	eval-mlogloss:0.07691	train-mlogloss:0.15158
# [939]	eval-mlogloss:0.07690	train-mlogloss:0.15148
# [940]	eval-mlogloss:0.07692	train-mlogloss:0.15141
# [941]	eval-mlogloss:0.07692	train-mlogloss:0.15125
# [942]	eval-mlogloss:0.07694	train-mlogloss:0.15117
# [943]	eval-mlogloss:0.07696	train-mlogloss:0.15099
# [944]	eval-mlogloss:0.07697	train-mlogloss:0.15080
# [945]	eval-mlogloss:0.07698	train-mlogloss:0.15071
# [946]	eval-mlogloss:0.07700	train-mlogloss:0.15051
# [947]	eval-mlogloss:0.07699	train-mlogloss:0.15029
# [948]	eval-mlogloss:0.07700	train-mlogloss:0.15011
# [949]	eval-mlogloss:0.07699	train-mlogloss:0.14987
# [950]	eval-mlogloss:0.07701	train-mlogloss:0.14967
# [951]	eval-mlogloss:0.07702	train-mlogloss:0.14952
# [952]	eval-mlogloss:0.07704	train-mlogloss:0.14935
# [953]	eval-mlogloss:0.07705	train-mlogloss:0.14911
# [954]	eval-mlogloss:0.07706	train-mlogloss:0.14894
# [955]	eval-mlogloss:0.07711	train-mlogloss:0.14882
# [956]	eval-mlogloss:0.07713	train-mlogloss:0.14853
# [957]	eval-mlogloss:0.07714	train-mlogloss:0.14835
# [958]	eval-mlogloss:0.07716	train-mlogloss:0.14817
# [959]	eval-mlogloss:0.07718	train-mlogloss:0.14801
# [960]	eval-mlogloss:0.07719	train-mlogloss:0.14780
# [961]	eval-mlogloss:0.07721	train-mlogloss:0.14760
# [962]	eval-mlogloss:0.07722	train-mlogloss:0.14746
# [963]	eval-mlogloss:0.07725	train-mlogloss:0.14730
# [964]	eval-mlogloss:0.07726	train-mlogloss:0.14714
# [965]	eval-mlogloss:0.07723	train-mlogloss:0.14697
# [966]	eval-mlogloss:0.07728	train-mlogloss:0.14679
# [967]	eval-mlogloss:0.07729	train-mlogloss:0.14657
# [968]	eval-mlogloss:0.07731	train-mlogloss:0.14639
# [969]	eval-mlogloss:0.07735	train-mlogloss:0.14623
# [970]	eval-mlogloss:0.07737	train-mlogloss:0.14605
# [971]	eval-mlogloss:0.07740	train-mlogloss:0.14593
# [972]	eval-mlogloss:0.07739	train-mlogloss:0.14576
# [973]	eval-mlogloss:0.07741	train-mlogloss:0.14557
# [974]	eval-mlogloss:0.07743	train-mlogloss:0.14538
# [975]	eval-mlogloss:0.07744	train-mlogloss:0.14519
# [976]	eval-mlogloss:0.07744	train-mlogloss:0.14501
# [977]	eval-mlogloss:0.07744	train-mlogloss:0.14483
# [978]	eval-mlogloss:0.07748	train-mlogloss:0.14462
# [979]	eval-mlogloss:0.07752	train-mlogloss:0.14446
# [980]	eval-mlogloss:0.07751	train-mlogloss:0.14437
# [981]	eval-mlogloss:0.07752	train-mlogloss:0.14423
# [982]	eval-mlogloss:0.07754	train-mlogloss:0.14407
# [983]	eval-mlogloss:0.07755	train-mlogloss:0.14389
# [984]	eval-mlogloss:0.07758	train-mlogloss:0.14369
# [985]	eval-mlogloss:0.07761	train-mlogloss:0.14347
# [986]	eval-mlogloss:0.07764	train-mlogloss:0.14334
# [987]	eval-mlogloss:0.07765	train-mlogloss:0.14322
# [988]	eval-mlogloss:0.07765	train-mlogloss:0.14303
# [989]	eval-mlogloss:0.07768	train-mlogloss:0.14286
# [990]	eval-mlogloss:0.07767	train-mlogloss:0.14272
# [991]	eval-mlogloss:0.07767	train-mlogloss:0.14261
# [992]	eval-mlogloss:0.07769	train-mlogloss:0.14253
# [993]	eval-mlogloss:0.07771	train-mlogloss:0.14232
# [994]	eval-mlogloss:0.07771	train-mlogloss:0.14211
# [995]	eval-mlogloss:0.07773	train-mlogloss:0.14192
# [996]	eval-mlogloss:0.07774	train-mlogloss:0.14182
# [997]	eval-mlogloss:0.07775	train-mlogloss:0.14162
# [998]	eval-mlogloss:0.07776	train-mlogloss:0.14144
# [999]	eval-mlogloss:0.07776	train-mlogloss:0.14128

# %%
# 최종 평가
y_val = y_val + 1
y_val_pred = y_val_pred + 1

# %%
# 혼동 행렬 계산
cm_val = confusion_matrix(y_val, y_val_pred, labels=[1, 2, 3, 4])


# 혼동 행렬 출력
print("Confusion Matrix for Validation Data:")
print(cm_val)


# 검증 데이터의 다중 CSI 계산
H_val = cm_val[0, 0] + cm_val[1, 1] + cm_val[2, 2]  # H11, H22, H33
F_val = (cm_val[0, 1] + cm_val[0, 2] + cm_val[1, 0] +
         cm_val[1, 2] + cm_val[2, 0] + cm_val[2, 1] +
         cm_val[3, 0] + cm_val[3, 1] + cm_val[3, 2])  # F12, F13, F21, F23, F31, F32, F41, F42, F43
M_val = cm_val[0, 3] + cm_val[1, 3] + cm_val[2, 3]  # M14, M24, M34

CSI_val = H_val / (H_val + F_val + M_val)
print(f"CSI for Validation Data: {CSI_val:.2f}")

# %%
# Feature importance 구하기
importance = bst.get_score(importance_type='weight')
importance_df = pd.DataFrame(importance.items(), columns=['Feature', 'Importance'])

# 중요도 내림차순으로 정렬
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# feature importance 출력
print("Feature Importance:")
print(importance_df)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.gca().invert_yaxis()
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()

# %%
# 테스트 데이터 예측
dtest = xgb.DMatrix(test_data_final_drop)
y_test_pred = bst.predict(dtest)

# %%
# y_test_pred 값별 비율 계산
unique, counts = np.unique(y_test_pred, return_counts=True)
ratios = counts / counts.sum()

# 값과 비율 출력
for value, ratio in zip(unique, ratios):
    print(f"Value: {value}, Ratio: {ratio:.9f}")

# %%
# 예측 결과를 원래 클래스 라벨로 변환
y_test_pred = y_test_pred.astype(int) + 1

# 제출하기 위해 test데이터 다시 불러옴
sub_test_data = pd.read_csv('/content/drive/MyDrive/날씨 콘테스트/fog_test.csv')
sub_test_data = sub_test_data.drop(columns=['fog_test.class'], errors='ignore')

# 예측 결과를 데이터프레임으로 저장
sub_test_data['fog_test.class'] = y_test_pred

# 예측 결과 저장
sub_test_data.to_csv('240184.csv', index=False)
sub_test_data["fog_test.class"].value_counts()

# %%
# 파일 다운로드
from google.colab import files
files.download('240184.csv')
